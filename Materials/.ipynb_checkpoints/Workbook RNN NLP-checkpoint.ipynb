# %% [markdown]
#  <h4 style='color:green;font-size:20px'>  Recurrent Neural Network <h4>

# %% [markdown]
# ![Screenshot%202023-07-21%20at%2012.11.42.png](attachment:Screenshot%202023-07-21%20at%2012.11.42.png)

# %% [markdown]
# ![Screenshot%202023-07-21%20at%2013.44.05.png](attachment:Screenshot%202023-07-21%20at%2013.44.05.png)

# %%
# Classify patient records and prescriptions

# %% [markdown]
# ![Screenshot%202023-07-21%20at%2013.57.42.png](attachment:Screenshot%202023-07-21%20at%2013.57.42.png)

# %% [markdown]
# ![Screenshot%202023-07-21%20at%2014.08.11.png](attachment:Screenshot%202023-07-21%20at%2014.08.11.png)
