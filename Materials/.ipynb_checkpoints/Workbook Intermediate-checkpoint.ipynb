# %% [markdown]
#  <h4 style='color:green;font-size:20px'>  Neural Network <h4>

# %% [markdown]
# ![Screenshot%202023-07-08%20at%2015.48.16.png](attachment:Screenshot%202023-07-08%20at%2015.48.16.png)
